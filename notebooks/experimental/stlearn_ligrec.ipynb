# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install @bokeh/jupyter_bokeh

# %%
# !pip install --upgrade ipykernel

# %%
import pandas as pd
import scanpy as sc
import stlearn as st
import numpy as np
import os
import os
os.environ["BOKEH_ALLOW_WS_ORIGIN"] = "16dh6h3v3qlll8ito1bl1hn3unnfoeqg7ap9n6da99c6bgjpsj1b"

# %%
data = sc.read_h5ad(r"C:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\STNav\data\processed\PipelineRun_Checkpoint\ST\Files\stlearn_cci_adata.h5ad")

# %%
st.pl.gene_plot_interactive(data)

# %%
st.pl.cluster_plot_interactive(data)
# Out:
# c:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\venv\lib\site-packages\stlearn\plotting\classes.py:723: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for i, cluster in enumerate(self.adata[0].obs.groupby(self.use_label)):
# c:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\venv\lib\site-packages\stlearn\plotting\classes.py:733: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for i, cluster in enumerate(self.query_adata.obs.groupby(self.use_label)):
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
# ...

# %%
st.pl.lr_plot_interactive(data)
# Out:
# WARNING:root:Dropping a patch because it contains a previously known reference (id='p1453'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='p1520'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# WARNING:root:Dropping a patch because it contains a previously known reference (id='p1587'). Most of the time this is harmless and usually a result of updating a model on one side of a communications channel while it was being removed on the other end.
# ...

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 145954 × 1461
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'total_counts', 'total_counts_Mt', 'pct_counts_Mt', 'total_counts_Ribo', 'pct_counts_Ribo', 'total_counts_Hb', 'pct_counts_Hb', 'leiden_clusters', '2_Smooth muscle', 'AT1', 'AT2', 'B cell lineage', 'EC arterial', 'EC capillary', 'EC venous', 'Fibroblasts', 'Innate lymphoid cell NK', 'Lymphatic EC differentiating', 'Lymphatic EC mature', 'Macrophages', 'Mast cells', 'T cell lineage', 'Unknown', 'spatial_ann_level_3_transferred_label', 'imagecol', 'imagerow', 'dominant_spot_cell_type'
#     var: 'gene_ids', 'feature_types', 'genome', 'Mt', 'Ribo', 'Hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
# ...

# %%
data.uns["dominant_spot_cell_type_colors"] = data.obs["dominant_spot_cell_type_colors"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dominant_spot_cell_type_colors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...

# %%
st.pl.spatialcci_plot_interactive(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 st.pl.spatialcci_plot_interactive(data)
#
# File c:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\venv\lib\site-packages\stlearn\plotting\cci_plot.py:1589, in spatialcci_plot_interactive(adata)
#    1581 def spatialcci_plot_interactive(adata: AnnData):
#    1582     """Plots the significant CCI in the spatial context interactively using Bokeh.
#    1583
#    1584     Parameters
#    (...)
#    1587         Data on which st.tl.cci.run & st.tl.cci.run_cci has been applied.
#    1588     """
# -> 1589     bokeh_object = BokehSpatialCciPlot(adata)
#    1590     output_notebook()
#    1591     show(bokeh_object.app, notebook_handle=True)
#
# File c:\Users\rafaelo\OneDrive - NTNU\Documents\Projects\venv\lib\site-packages\stlearn\plotting\classes_bokeh.py:1042, in BokehSpatialCciPlot.__init__(self, adata)
# ...
