# %%
import scanpy as sc
adata: sc.AnnData = sc.read_h5ad(filename=r"/mnt/work/RO_src/data/raw/scRNA/SCLC/SCLC_Annotated_pp.h5ad")

# %%
adata.X = adata.layers["lognorm_counts"].copy()

# %% [markdown]
# # highly variable genes

# %%
sc.pl.highly_variable_genes(adata_or_result=adata)

# %% [markdown]
# # highest expressed genes plot

# %%
sc.pl.highest_expr_genes(adata=adata, n_top=20)

# %% [markdown]
# # pca plot

# %%
sc.pl.pca(adata=adata, color='cell_type_fine', annotate_var_explained=True)

# %% [markdown]
# # pca loadings plot

# %%
sc.pl.pca_loadings(adata=adata, components='1,2')

# %% [markdown]
# # pca variance ratio plot

# %%
sc.pl.pca_variance_ratio(adata=adata, log=False,n_pcs=30)

# %% [markdown]
# # umap plot

# %%
sc.pl.umap(adata=adata, color='cell_type_fine')

# %% [markdown]
# # tsne plot

# %%
sc.pl.tsne(adata=adata, color='cell_type_fine')

# %% [markdown]
# # proportion cell type

# %%
      "scRNA_proportion_per_cell_plot.png": {
        "usage": true,
        "func_str": "proportion_per_cell_plot",
        "adata_to_use": "preprocessed_adata",
        "data_type": "scRNA",
        "params": {
          "adata": "adata",
          "group": "cell_type_fine",
          "condition": "leiden_clusters",
          "show": false
        }
      }

# %% [markdown]
# # correlation matrix

# %%
sc.pl.correlation_matrix(adata=adata, groupby='cell_type_fine')

# %% [markdown]
# # heatmap

# %%
sc.tl.rank_genes_groups(adata, groupby='cell_type_fine', method='wilcoxon', layer="lognorm_counts", use_raw=False)
# Out:
# /mnt/work/RO_src/venv/stnav_venv/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:435: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /mnt/work/RO_src/venv/stnav_venv/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:437: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# ...

# %%
adata.var_names
# Out:
# Index(['A1BG', 'A1CF', 'A2M', 'A4GALT', 'A4GNT', 'AAAS', 'AACS', 'AADAC',
#        'AADAT', 'PRXL2C',
#        ...
#        'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', name='feature_name', length=19730)

# %%
sc.pl.heatmap(adata=adata, var_names=['A2M', 'A4GALT', 'A4GNT', 'AAAS'],use_raw=False,
 groupby='cell_type_fine', cmap="bwr", layer="lognorm_counts",figsize=(10, 60))

# %% [markdown]
# # rank genes groups heatmap plot

# %%
sc.pl.rank_genes_groups_heatmap(adata=adata,use_raw=False, layer="lognorm_counts",n_genes=5, groups=None, show_gene_labels=True,  groupby="cell_type_fine",figsize=(20, 75))

# %% [markdown]
# # rank genes groups

# %%
sc.pl.rank_genes_groups(adata=adata,use_raw=False, layer="lognorm_counts", n_genes=20,groups=None)

# %% [markdown]
# # rank genes groups matrixplot

# %%
sc.pl.rank_genes_groups_matrixplot(adata=adata, use_raw=False, layer="lognorm_counts",n_genes=5, groupby="cell_type_fine",figsize=(20, 5))

# %% [markdown]
# # rank genes groups stacked violin plot

# %%
sc.pl.rank_genes_groups_stacked_violin(adata=adata,use_raw=False, layer="lognorm_counts",groups=None, n_genes=5, groupby="cell_type_fine",figsize=(20, 5))

# %% [markdown]
# # rank genes groups tracksplot

# %%
sc.pl.rank_genes_groups_tracksplot(adata=adata, use_raw=False, layer="lognorm_counts",n_genes=5,figsize=(20, 5))

# %% [markdown]
# # rank genes groups dotplot

# %%
sc.pl.rank_genes_groups_dotplot(adata=adata, use_raw=False, layer="lognorm_counts",n_genes=5, key="wilcoxon", groupby="cell_type_fine", dendogram=True,figsize=(20, 5))

# %% [markdown]
# # rank genes groups violin

# %%
sc.pl.rank_genes_groups_violin(adata=adata, use_raw=False, layer="lognorm_counts",n_genes=5, key="wilcoxon",groups=None,figsize=(20, 5))

# %% [markdown]
# # violin

# %%
sc.pl.violin(adata=adata, keys=[
            "n_genes_by_counts",
            "total_counts",
            "pct_counts_mt",
            "pct_counts_ribo",
            "pct_counts_hb"
          ], litter=0.4, rotation=45)

# %% [markdown]
# # stacked violin

# %%
sc.pl.stacked_violin(adata=adata, var_names=["Samd11","Perm1", "Hes4"],groupby="cell_type_fine")

# %% [markdown]
# # dotplot

# %%
sc.pl.dotplot(adata=adata,  var_names=["Samd11","Perm1", "Hes4"],groupby="cell_type_fine")
